# %% [markdown]
# <p style = "font-size : 50px; color : #532e1c ; font-family : 'Comic Sans MS'; text-align : center; background-color : #bedcfa; border-radius: 5px 5px;"><strong>Churn Modelling Using ANN</strong></p>

# %%
# !pip install --upgrade kagglehub
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.11/dist-packages (0.3.11)
# Collecting kagglehub
#   Downloading kagglehub-0.3.12-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2025.1.31)
# Downloading kagglehub-0.3.12-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: kagglehub
#   Attempting uninstall: kagglehub
#     Found existing installation: kagglehub 0.3.11
#     Uninstalling kagglehub-0.3.11:
#       Successfully uninstalled kagglehub-0.3.11
# Successfully installed kagglehub-0.3.12

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shrutimechlearn/churn-modelling")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/shrutimechlearn/churn-modelling?dataset_version_number=1...
# 100%|██████████| 262k/262k [00:00<00:00, 61.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/shrutimechlearn/churn-modelling/versions/1

# %%
# necessary imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv('/root/.cache/kagglehub/datasets/shrutimechlearn/churn-modelling/versions/1/Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #f9b208; border-radius: 5px 5px;"><strong>Exploratory Data Analysis (EDA)</strong></p>

# %%
# checking for null values

df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
values = df.Exited.value_counts()
labels = ['Not Exited', 'Exited']

fig, ax = plt.subplots(figsize = (4, 3), dpi = 100)
explode = (0, 0.09)

patches, texts, autotexts = ax.pie(values, labels = labels, autopct = '%1.2f%%', shadow = True,
                                   startangle = 90, explode = explode)

plt.setp(texts, color = 'grey')
plt.setp(autotexts, size = 8, color = 'white')
autotexts[1].set_color('black')
plt.show()

# %% [markdown]
# <p style = "font-size : 20px; color : #34656d ; font-family : 'Comic Sans MS'; "><strong>20% of the customers have churned and 80% haven't.</strong></p>

# %%
fig, ax = plt.subplots(3, 2, figsize = (18, 15))

sns.countplot(x='Geography', hue='Exited', data=df, ax=ax[0][0])
sns.countplot(x='Gender', hue='Exited', data=df, ax=ax[0][1])
sns.countplot(x='Tenure', hue='Exited', data=df, ax=ax[1][0])
sns.countplot(x='NumOfProducts', hue='Exited', data=df, ax=ax[1][1])
sns.countplot(x='HasCrCard', hue='Exited', data=df, ax=ax[2][0])
sns.countplot(x='IsActiveMember', hue='Exited', data=df, ax=ax[2][1])

plt.tight_layout()
plt.show()

# %% [markdown]
# <p style = "font-size : 30px; color : #4e8d7c ; font-family : 'Comic Sans MS';"><strong>From above Plots we can conclude that:-</strong></p>
#
# <ul>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Majority of the customers are from france but most customers which churned are from germany maybe because of lack of resources as there are not many customers.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>The proportion of female customers churning is also greater than that of female customers.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Majority of customers have tenure between 1 to 9 and churing rate is also high between these tenures.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Most of the customers have 1 or 2 products and most customers which churned are having 1 products maybe they are not satisfied so they are churning.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Interestingly, majority of customers that churned are those with credit cards but this can be a coincidence as majority of customers have credit cards.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Unsurprisingly the inactive members have a greater churn and the overall proportion of inactive members is also very high.</strong></li>

# %%
# visualizing continuous variables

fig, ax = plt.subplots(2, 2, figsize = (16, 10))

sns.boxplot(x = 'Exited', y = 'CreditScore', data = df, ax = ax[0][0])
sns.boxplot(x = 'Exited', y = 'Age', data = df, ax = ax[0][1])
sns.boxplot(x = 'Exited', y = 'Balance', data = df, ax = ax[1][0])
sns.boxplot(x = 'Exited', y = 'EstimatedSalary', data = df, ax = ax[1][1])

plt.tight_layout()
plt.show()

# %% [markdown]
# <p style = "font-size : 30px; color : #4e8d7c ; font-family : 'Comic Sans MS';"><strong>From above Plots we can conclude that:-</strong></p>
#
# <ul>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>There is no significant difference in credit score distribution etween custers which are churned or not.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>The older customers are churning more than younger ones.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Bank is loosing customers with significant bank balance.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Estimated Salary does not have a significant on the likelihood to churn.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Interestingly, majority of customers that churned are those with credit cards but this can be a coincidence as majority of customers have credit cards.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Unsurprisingly the inactive members have a greater churn and the overall proportion of inactive members is also very high.</strong></li>

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Compute correlation matrix
corr = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(20, 12))
sns.heatmap(corr, linewidths=1, annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# <p style = "font-size : 20px; color : #34656d ; font-family : 'Comic Sans MS'; "><strong>We can say that there is no multicolinearity present in data.</strong></p>

# %%
# dropping useless columns

df.drop(columns = ['RowNumber', 'CustomerId', 'Surname'], axis = 1, inplace = True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.Geography.value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
# Encoding categorical variables

df['Geography'] = df['Geography'].map({'France' : 0, 'Germany' : 1, 'Spain' : 2})
df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       1   42       2       0.00              1
# 1          608          2       1   41       1   83807.86              1
# 2          502          0       1   42       8  159660.80              3
# 3          699          0       1   39       1       0.00              2
# 4          850          2       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# creating features and label

from tensorflow.keras.utils import to_categorical

X = df.drop('Exited', axis = 1)
y = to_categorical(df.Exited)

# %%
# splitting data into training set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Scaling data

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #f9b208; border-radius: 5px 5px;"><strong>Building ANN </strong></p>

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization

# initializing ann
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6945 - loss: 0.6507 - val_accuracy: 0.7932 - val_loss: 0.5404
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8180 - loss: 0.4631 - val_accuracy: 0.8216 - val_loss: 0.4160
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8409 - loss: 0.3932 - val_accuracy: 0.8472 - val_loss: 0.3730
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8472 - loss: 0.3763 - val_accuracy: 0.8508 - val_loss: 0.3657
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8405 - loss: 0.3850 - val_accuracy: 0.8524 - val_loss: 0.3586
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8406 - loss: 0.3838 - val_accuracy: 0.8548 - val_loss: 0.3600
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8383 - loss: 0.3845 - val_accuracy: 0.8552 - val_loss: 0.3576
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8553 - loss: 0.3593 - val_accuracy: 0.8488 - val_loss: 0.3596
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8389 - loss: 0.3779 - val_accuracy: 0.8504 - val_loss: 0.3576
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8455 - loss: 0.3763 - val_accuracy: 0.8524 - val_loss: 0.3586
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8484 - loss: 0.3641 - val_accuracy: 0.8504 - val_loss: 0.3587
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8450 - loss: 0.3679 - val_accuracy: 0.8536 - val_loss: 0.3564
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8367 - loss: 0.3813 - val_accuracy: 0.8528 - val_loss: 0.3565
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8393 - loss: 0.3784 - val_accuracy: 0.8520 - val_loss: 0.3592
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8530 - loss: 0.3615 - val_accuracy: 0.8520 - val_loss: 0.3624
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8504 - loss: 0.3554 - val_accuracy: 0.8528 - val_loss: 0.3559
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8492 - loss: 0.3653 - val_accuracy: 0.8520 - val_loss: 0.3577
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8412 - loss: 0.3762 - val_accuracy: 0.8508 - val_loss: 0.3546
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8456 - loss: 0.3745 - val_accuracy: 0.8524 - val_loss: 0.3605
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8488 - loss: 0.3617 - val_accuracy: 0.8548 - val_loss: 0.3546
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8472 - loss: 0.3712 - val_accuracy: 0.8516 - val_loss: 0.3608
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8412 - loss: 0.3797 - val_accuracy: 0.8524 - val_loss: 0.3551
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8494 - loss: 0.3614 - val_accuracy: 0.8516 - val_loss: 0.3539
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8532 - loss: 0.3588 - val_accuracy: 0.8548 - val_loss: 0.3551
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8462 - loss: 0.3617 - val_accuracy: 0.8540 - val_loss: 0.3573
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8494 - loss: 0.3582 - val_accuracy: 0.8536 - val_loss: 0.3583
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8488 - loss: 0.3633 - val_accuracy: 0.8556 - val_loss: 0.3562
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8470 - loss: 0.3734 - val_accuracy: 0.8524 - val_loss: 0.3592
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8536 - loss: 0.3551 - val_accuracy: 0.8524 - val_loss: 0.3557
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8431 - loss: 0.3759 - val_accuracy: 0.8520 - val_loss: 0.3585
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8511 - loss: 0.3599 - val_accuracy: 0.8528 - val_loss: 0.3633
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8457 - loss: 0.3726 - val_accuracy: 0.8520 - val_loss: 0.3585
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8549 - loss: 0.3499 - val_accuracy: 0.8500 - val_loss: 0.3591
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8447 - loss: 0.3670 - val_accuracy: 0.8532 - val_loss: 0.3604
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8547 - loss: 0.3561 - val_accuracy: 0.8512 - val_loss: 0.3568
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8505 - loss: 0.3568 - val_accuracy: 0.8528 - val_loss: 0.3584
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8510 - loss: 0.3584 - val_accuracy: 0.8540 - val_loss: 0.3563
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8437 - loss: 0.3679 - val_accuracy: 0.8540 - val_loss: 0.3563
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8569 - loss: 0.3480 - val_accuracy: 0.8520 - val_loss: 0.3594
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8492 - loss: 0.3641 - val_accuracy: 0.8532 - val_loss: 0.3585
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8529 - loss: 0.3559 - val_accuracy: 0.8528 - val_loss: 0.3595
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8477 - loss: 0.3656 - val_accuracy: 0.8528 - val_loss: 0.3609
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8515 - loss: 0.3598 - val_accuracy: 0.8480 - val_loss: 0.3572
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8496 - loss: 0.3628 - val_accuracy: 0.8504 - val_loss: 0.3552
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8485 - loss: 0.3614 - val_accuracy: 0.8548 - val_loss: 0.3566
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8517 - loss: 0.3672 - val_accuracy: 0.8520 - val_loss: 0.3543
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8437 - loss: 0.3661 - val_accuracy: 0.8528 - val_loss: 0.3573
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8489 - loss: 0.3652 - val_accuracy: 0.8536 - val_loss: 0.3525
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8482 - loss: 0.3657 - val_accuracy: 0.8516 - val_loss: 0.3576
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8465 - loss: 0.3654 - val_accuracy: 0.8520 - val_loss: 0.3562
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8512 - loss: 0.3650 - val_accuracy: 0.8536 - val_loss: 0.3588
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8563 - loss: 0.3494 - val_accuracy: 0.8516 - val_loss: 0.3572
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8443 - loss: 0.3772 - val_accuracy: 0.8532 - val_loss: 0.3557
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8473 - loss: 0.3646 - val_accuracy: 0.8500 - val_loss: 0.3571
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8498 - loss: 0.3672 - val_accuracy: 0.8500 - val_loss: 0.3577
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8478 - loss: 0.3664 - val_accuracy: 0.8532 - val_loss: 0.3602
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8490 - loss: 0.3693 - val_accuracy: 0.8524 - val_loss: 0.3602
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8492 - loss: 0.3665 - val_accuracy: 0.8504 - val_loss: 0.3571
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8460 - loss: 0.3692 - val_accuracy: 0.8504 - val_loss: 0.3590
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8449 - loss: 0.3669 - val_accuracy: 0.8532 - val_loss: 0.3589
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8430 - loss: 0.3724 - val_accuracy: 0.8516 - val_loss: 0.3599
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8564 - loss: 0.3620 - val_accuracy: 0.8508 - val_loss: 0.3570
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8468 - loss: 0.3767 - val_accuracy: 0.8520 - val_loss: 0.3583
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8482 - loss: 0.3700 - val_accuracy: 0.8516 - val_loss: 0.3603
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8551 - loss: 0.3545 - val_accuracy: 0.8516 - val_loss: 0.3565
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8486 - loss: 0.3638 - val_accuracy: 0.8516 - val_loss: 0.3585
# Epoch 67/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8474 - loss: 0.3574 - val_accuracy: 0.8496 - val_loss: 0.3599
# Epoch 68/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8588 - loss: 0.3508 - val_accuracy: 0.8516 - val_loss: 0.3637
# Epoch 69/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8521 - loss: 0.3555 - val_accuracy: 0.8492 - val_loss: 0.3654
# Epoch 70/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8535 - loss: 0.3564 - val_accuracy: 0.8512 - val_loss: 0.3614
# Epoch 71/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8468 - loss: 0.3639 - val_accuracy: 0.8524 - val_loss: 0.3588
# Epoch 72/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8509 - loss: 0.3611 - val_accuracy: 0.8488 - val_loss: 0.3628
# Epoch 73/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8448 - loss: 0.3721 - val_accuracy: 0.8496 - val_loss: 0.3616
# Epoch 74/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8496 - loss: 0.3641 - val_accuracy: 0.8500 - val_loss: 0.3596
# Epoch 75/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8478 - loss: 0.3614 - val_accuracy: 0.8504 - val_loss: 0.3637
# Epoch 76/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8510 - loss: 0.3606 - val_accuracy: 0.8480 - val_loss: 0.3656
# Epoch 77/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8542 - loss: 0.3566 - val_accuracy: 0.8516 - val_loss: 0.3607
# Epoch 78/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8524 - loss: 0.3579 - val_accuracy: 0.8484 - val_loss: 0.3605
# Epoch 79/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8380 - loss: 0.3720 - val_accuracy: 0.8524 - val_loss: 0.3572
# Epoch 80/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8465 - loss: 0.3679 - val_accuracy: 0.8516 - val_loss: 0.3574
# Epoch 81/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8563 - loss: 0.3520 - val_accuracy: 0.8540 - val_loss: 0.3603
# Epoch 82/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8524 - loss: 0.3595 - val_accuracy: 0.8512 - val_loss: 0.3580
# Epoch 83/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8578 - loss: 0.3503 - val_accuracy: 0.8516 - val_loss: 0.3627
# Epoch 84/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8504 - loss: 0.3620 - val_accuracy: 0.8516 - val_loss: 0.3605
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8483 - loss: 0.3617 - val_accuracy: 0.8508 - val_loss: 0.3615
# Epoch 86/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8482 - loss: 0.3689 - val_accuracy: 0.8544 - val_loss: 0.3588
# Epoch 87/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8453 - loss: 0.3681 - val_accuracy: 0.8528 - val_loss: 0.3550
# Epoch 88/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8510 - loss: 0.3632 - val_accuracy: 0.8528 - val_loss: 0.3605
# Epoch 89/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8452 - loss: 0.3677 - val_accuracy: 0.8544 - val_loss: 0.3550
# Epoch 90/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8425 - loss: 0.3718 - val_accuracy: 0.8528 - val_loss: 0.3585
# Epoch 91/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8523 - loss: 0.3620 - val_accuracy: 0.8504 - val_loss: 0.3544
# Epoch 92/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8485 - loss: 0.3555 - val_accuracy: 0.8548 - val_loss: 0.3574
# Epoch 93/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8456 - loss: 0.3661 - val_accuracy: 0.8516 - val_loss: 0.3608
# Epoch 94/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8461 - loss: 0.3619 - val_accuracy: 0.8532 - val_loss: 0.3571
# Epoch 95/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8445 - loss: 0.3720 - val_accuracy: 0.8544 - val_loss: 0.3595
# Epoch 96/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8498 - loss: 0.3586 - val_accuracy: 0.8524 - val_loss: 0.3622
# Epoch 97/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8499 - loss: 0.3611 - val_accuracy: 0.8536 - val_loss: 0.3580
# Epoch 98/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8497 - loss: 0.3686 - val_accuracy: 0.8480 - val_loss: 0.3622
# Epoch 99/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8474 - loss: 0.3605 - val_accuracy: 0.8520 - val_loss: 0.3613
# Epoch 100/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8518 - loss: 0.3590 - val_accuracy: 0.8504 - val_loss: 0.3574

# %% [markdown]
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #f9b208; border-radius: 5px 5px;"><strong>Visualizing Training and Validation Loss</strong></p>

# %%
plt.figure(figsize=(12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epoch = range(1, 101)

# Plotting the loss values
sns.lineplot(x=epoch, y=train_loss, label='Training Loss')
sns.lineplot(x=epoch, y=val_loss, label='Validation Loss')

plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #f9b208; border-radius: 5px 5px;"><strong>Visualizing Training and Validation accuracy</strong></p>

# %%
plt.figure(figsize=(12, 6))

train_accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']
epoch = range(1, 101)

# Plotting the accuracy values
sns.lineplot(x=epoch, y=train_accuracy, label='Training accuracy')
sns.lineplot(x=epoch, y=val_accuracy, label='Validation accuracy')

plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8447 - loss: 0.3742
# Accuracy of model is 0.8503999710083008

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 10)             │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │            77 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7)              │            28 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            16 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 747 (2.92 KB)
#  Trainable params: 237 (948.00 B)
#  Non-trainable params: 34 (136.00 B)
#  Optimizer params: 476 (1.86 KB)

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes = True)

# %% [markdown]
# <p style = "font-size : 25px; color : #f55c47 ; font-family : 'Comic Sans MS'; "><strong>If you like my work, please do Upvote.</strong></p>
